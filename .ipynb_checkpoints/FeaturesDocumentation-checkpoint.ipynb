# %% [markdown]
# # Time Series Features
# ## Isadora Nun, Pavlos Protopapas, ....
#
# Time Series features are important for all kind of classification .. In this document we described the library ....

# %% [markdown]
# ### Import a light curve
# A typical lightcurve from MACHO or ... is shown below

# %%
# %matplotlib inline
from Feature import FeatureSpace
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.graphics.tsaplots as tsaplots
import pandas

# %%
def LeerLC_MACHO(fid):
    saltos_linea = 3
    delimiter = ' '
    for i in range(0,saltos_linea):
        fid.next()
    LC = []

    for lines in fid:
        str_line = lines.strip().split()
        floats = map(float, str_line)
        #numbers = (number for number in str_line.split())
        LC.append(floats)

    LC = np.asarray(LC)
    return LC

#Opening the blue band
fid=open('lc_1.4652.1527.B.mjd','r')

lc = LeerLC_MACHO(fid)

data  = lc[:,1]
error = lc[:,2]
mjd = lc[:,0]

#Opening the red band

fid2=open('lc_1.4652.1527.R.mjd','r')

lc2 = LeerLC_MACHO(fid2)

second_data  = lc2[:,1]

# %%
plt.plot(mjd, data, 'b*-')
plt.xlabel("MJD")
plt.ylabel("Magnitude")

# %% [markdown]
# ### Standard deviaton $\sigma$
# The $\sigma$ is the standard deviation of the sample defined as:
#
# $$ \sigma = \sum_{i} \frac{(y_i-\hat{y})^2}{N-1} $$

# %%
a = FeatureSpace(featureList=['Std'])
a=a.calculateFeature(data)

# %%
print a.result(method='dict')
# Out:
# {'Std': 0.067275065303153039}

# %% [markdown]
# For example, a white noise timeseries should have $\sigma=1$

# %%
data2 = np.random.normal(size=1000000)
a = FeatureSpace(featureList=['Std' ] )
a=a.calculateFeature(data2)
print a.result(method='dict')
# Out:
# {'Std': 1.0003290701536804}

# %%
N=100
mjd3 = np.arange(N)
Period = 1.5
cov = np.zeros([N,N])
mean = np.zeros(N)
for i in np.arange(N):
    for j in np.arange(N):
        #print (2.0*np.pi/Period) * (i-j)**2
        cov[i,j] = np.exp( -(np.sin( (np.pi/Period) *(i-j))**2))
#cov = np.diagflat((np.ones(10)))
data3=np.random.multivariate_normal(mean, cov)
plt.plot(mjd3,data3)

# %%
from Feature import FeatureSpace
a = FeatureSpace(featureList=['PeriodLS'],PeriodLS=mjd3)
a=a.calculateFeature(data3)
print (1)/a.result(method='array')/Period, 1./a.result(method='array'), Period
# Out:
# [ 2.] [ 3.] 1.5

# %%
a = FeatureSpace(featureList=['PeriodLS' ],PeriodLS=mjd )
a=a.calculateFeature(data)
print 1./a.result(method='array')
# Out:
# [ 1.2508297]

# %%
T = 2*0.555774894888000 # 2.0 *1./a.result(method='array')
new_b=np.mod(mjd, T) / T;
idx=np.argsort(2*new_b)
plt.plot( new_b, data, 'b*')

# %%
# Out:
# array([ 0.43678976,  0.44062521,  0.44452062, ...,  0.88786972,
#         0.86251392,  0.85345642])
